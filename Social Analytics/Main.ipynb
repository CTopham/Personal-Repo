# %%
#Analyzing the news sentiment
#BBC, CBS, CNN, Fox, and New York times.
#The first plot: scatter from the past 100 tweets of each outlet, each plot is the compound. sort by time stamp
#second plot: bar plot of overall sentiment of each outlet,  aggregate the compound sentiment

#Dependencies
import json
import tweepy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
from datetime import datetime
from textblob import TextBlob
import matplotlib.patches as mpatches

#Keys to the kingdom
from config import Consumer
from config import ConsumerSecret
from config import Access
from config import AccessSecret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(Consumer, ConsumerSecret)
auth.set_access_token(Access, AccessSecret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

#Vader for the sentiment analytics
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
target_tags = ["@BBC", "@CBS", "@CNN", "@FoxNews","@nytimes"]

# %%
#Pulling data from Twitter API
counter = 0
sentiments = []
while counter < 4:
    for tag in target_tags:
        target_user = tag
        tweet_count = 0
        for x in range(5):
            public_tweets = api.user_timeline(target_user, page = x +1)
            for tweet in public_tweets:
                compound = analyzer.polarity_scores(tweet["text"])["compound"]
                pos = analyzer.polarity_scores(tweet["text"])["pos"]
                neu = analyzer.polarity_scores(tweet["text"])["neu"]
                neg = analyzer.polarity_scores(tweet["text"])["neg"]
                raw_time = tweet["created_at"]
                converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")
                words = tweet["text"]
                print(analyzer.polarity_scores(tweet["text"]))
                sentiments.append({"Date": converted_time,
                                   "Tweet": words,
                                   "Compound": compound,
                                   "Positive": pos,
                                   "Negative": neu,
                                   "Neutral": neg,
                                   "Outlet": tag,
                                   "Tweets Ago": tweet_count,})
                counter = counter + 1 
                tweet_count = tweet_count + 1
                converted_time = []
                words = []
# Out:
# {'neg': 0.152, 'neu': 0.662, 'pos': 0.185, 'compound': 0.128}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.3404}
# {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.1779}
# {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.6351}
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.7579}
# {'neg': 0.0, 'neu': 0.42, 'pos': 0.58, 'compound': 0.93}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.154, 'neu': 0.846, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6369}
# {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.5983}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.5719}
# {'neg': 0.116, 'neu': 0.81, 'pos': 0.073, 'compound': -0.2144}
# {'neg': 0.0, 'neu': 0.623, 'pos': 0.377, 'compound': 0.8715}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
# {'neg': 0.09, 'neu': 0.697, 'pos': 0.213, 'compound': 0.4574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.123, 'neu': 0.751, 'pos': 0.126, 'compound': 0.0258}
# {'neg': 0.099, 'neu': 0.901, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.109, 'neu': 0.697, 'pos': 0.194, 'compound': 0.4522}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.712, 'pos': 0.288, 'compound': 0.784}
# {'neg': 0.534, 'neu': 0.466, 'pos': 0.0, 'compound': -0.3164}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.8268}
# {'neg': 0.295, 'neu': 0.581, 'pos': 0.124, 'compound': -0.6249}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.6908}
# {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'compound': 0.784}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.296}
# {'neg': 0.312, 'neu': 0.688, 'pos': 0.0, 'compound': -0.8225}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.7506}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.098, 'neu': 0.902, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.056, 'neu': 0.837, 'pos': 0.108, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.256, 'neu': 0.744, 'pos': 0.0, 'compound': -0.7351}
# {'neg': 0.192, 'neu': 0.692, 'pos': 0.115, 'compound': -0.25}
# {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.2942}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.6114}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.134, 'neu': 0.866, 'pos': 0.0, 'compound': -0.3064}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.5994}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.124, 'neu': 0.827, 'pos': 0.049, 'compound': -0.4588}
# {'neg': 0.194, 'neu': 0.806, 'pos': 0.0, 'compound': -0.6249}
# {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.7783}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.4926}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.108, 'neu': 0.68, 'pos': 0.212, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.296}
# {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compound': 0.508}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.7959}
# {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.807}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.062, 'neu': 0.78, 'pos': 0.157, 'compound': 0.5319}
# {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.5399}
# {'neg': 0.185, 'neu': 0.7, 'pos': 0.115, 'compound': -0.34}
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.7003}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.7184}
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.9451}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.6996}
# {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.8997}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.066, 'neu': 0.623, 'pos': 0.311, 'compound': 0.7081}
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.636}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.5562}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.072, 'neu': 0.619, 'pos': 0.309, 'compound': 0.7845}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.6514}
# {'neg': 0.0, 'neu': 0.92, 'pos': 0.08, 'compound': 0.1867}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.839, 'pos': 0.161, 'compound': 0.6166}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.6514}
# {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.7088}
# {'neg': 0.157, 'neu': 0.766, 'pos': 0.077, 'compound': -0.4939}
# {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.6514}
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.6115}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6696}
# {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.539}
# {'neg': 0.0, 'neu': 0.917, 'pos': 0.083, 'compound': 0.2244}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.883, 'pos': 0.117, 'compound': 0.4926}
# {'neg': 0.092, 'neu': 0.795, 'pos': 0.113, 'compound': 0.1275}
# {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 0.553, 'pos': 0.447, 'compound': 0.8658}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'compound': 0.8625}
# {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.4926}
# {'neg': 0.23, 'neu': 0.619, 'pos': 0.15, 'compound': -0.2023}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.6705}
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 0.718, 'pos': 0.282, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 0.849, 'pos': 0.151, 'compound': 0.4939}
# {'neg': 0.21, 'neu': 0.79, 'pos': 0.0, 'compound': -0.6981}
# {'neg': 0.092, 'neu': 0.749, 'pos': 0.159, 'compound': 0.4547}
# {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'compound': 0.8591}
# {'neg': 0.151, 'neu': 0.615, 'pos': 0.234, 'compound': 0.4885}
# {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.7717}
# {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.6908}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.5562}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.4482}
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.784}
# {'neg': 0.0, 'neu': 0.571, 'pos': 0.429, 'compound': 0.9359}
# {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.7644}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.5093}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 0.884, 'pos': 0.116, 'compound': 0.4404}
# {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6124}
# {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.68}
# {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'compound': 0.8619}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.114, 'neu': 0.669, 'pos': 0.217, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.7717}
# {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.185, 'neu': 0.707, 'pos': 0.109, 'compound': -0.34}
# {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'compound': -0.2023}
# {'neg': 0.15, 'neu': 0.791, 'pos': 0.059, 'compound': -0.5106}
# {'neg': 0.356, 'neu': 0.644, 'pos': 0.0, 'compound': -0.7351}
# {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.6369}
# {'neg': 0.238, 'neu': 0.671, 'pos': 0.091, 'compound': -0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.114, 'neu': 0.669, 'pos': 0.217, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.2732}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.089, 'neu': 0.61, 'pos': 0.301, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.34}
# {'neg': 0.186, 'neu': 0.814, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.3182}
# {'neg': 0.137, 'neu': 0.731, 'pos': 0.132, 'compound': -0.0258}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.186, 'neu': 0.814, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'compound': -0.4003}
# {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'compound': 0.296}
# {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'compound': 0.5367}
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4215}
# {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'compound': 0.7717}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.204, 'neu': 0.796, 'pos': 0.0, 'compound': -0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.4215}
# {'neg': 0.43, 'neu': 0.57, 'pos': 0.0, 'compound': -0.7783}
# {'neg': 0.238, 'neu': 0.671, 'pos': 0.091, 'compound': -0.5267}
# {'neg': 0.185, 'neu': 0.707, 'pos': 0.109, 'compound': -0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.152, 'neu': 0.848, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.5859}
# {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.25}
# {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.2023}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.356, 'neu': 0.644, 'pos': 0.0, 'compound': -0.7351}
# {'neg': 0.15, 'neu': 0.791, 'pos': 0.059, 'compound': -0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.128, 'neu': 0.722, 'pos': 0.15, 'compound': 0.1027}
# {'neg': 0.153, 'neu': 0.744, 'pos': 0.103, 'compound': -0.296}
# {'neg': 0.172, 'neu': 0.714, 'pos': 0.113, 'compound': -0.1027}
# {'neg': 0.17, 'neu': 0.83, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.065, 'neu': 0.837, 'pos': 0.098, 'compound': 0.1779}
# {'neg': 0.148, 'neu': 0.707, 'pos': 0.145, 'compound': -0.2732}
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.3089}
# {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'compound': -0.2023}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'compound': -0.2023}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.114, 'neu': 0.669, 'pos': 0.217, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.206, 'neu': 0.794, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'compound': 0.8074}
# {'neg': 0.136, 'neu': 0.714, 'pos': 0.15, 'compound': 0.0516}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'compound': -0.5994}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.802}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.114, 'neu': 0.669, 'pos': 0.217, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.1779}
# {'neg': 0.0, 'neu': 0.923, 'pos': 0.077, 'compound': 0.1901}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.6739}
# {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.2732}
# {'neg': 0.593, 'neu': 0.407, 'pos': 0.0, 'compound': -0.8807}
# {'neg': 0.192, 'neu': 0.684, 'pos': 0.124, 'compound': -0.3818}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.4939}
# {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.7287}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# {'neg': 0.222, 'neu': 0.778, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.21, 'neu': 0.694, 'pos': 0.095, 'compound': -0.3919}
# {'neg': 0.335, 'neu': 0.577, 'pos': 0.088, 'compound': -0.7506}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.34}
# {'neg': 0.215, 'neu': 0.613, 'pos': 0.172, 'compound': 0.0772}
# {'neg': 0.593, 'neu': 0.407, 'pos': 0.0, 'compound': -0.8807}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.65, 'pos': 0.35, 'compound': 0.7906}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.133, 'neu': 0.644, 'pos': 0.223, 'compound': 0.2732}
# {'neg': 0.615, 'neu': 0.385, 'pos': 0.0, 'compound': -0.9153}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'compound': -0.8402}
# {'neg': 0.261, 'neu': 0.739, 'pos': 0.0, 'compound': -0.7184}
# {'neg': 0.358, 'neu': 0.642, 'pos': 0.0, 'compound': -0.7717}
# {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.6739}
# {'neg': 0.265, 'neu': 0.735, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.4939}
# {'neg': 0.117, 'neu': 0.745, 'pos': 0.138, 'compound': 0.1027}
# {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.397, 'pos': 0.603, 'compound': 0.9349}
# {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4939}
# {'neg': 0.187, 'neu': 0.576, 'pos': 0.237, 'compound': 0.1779}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.396, 'neu': 0.604, 'pos': 0.0, 'compound': -0.7096}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4019}
# {'neg': 0.132, 'neu': 0.714, 'pos': 0.154, 'compound': 0.1027}
# {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.5267}
# {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'compound': -0.4939}
# {'neg': 0.099, 'neu': 0.852, 'pos': 0.049, 'compound': -0.2732}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.182, 'neu': 0.818, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.5106}
# {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.105, 'neu': 0.766, 'pos': 0.129, 'compound': 0.128}
# {'neg': 0.282, 'neu': 0.718, 'pos': 0.0, 'compound': -0.7096}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.105, 'neu': 0.767, 'pos': 0.128, 'compound': 0.1189}
# {'neg': 0.185, 'neu': 0.815, 'pos': 0.0, 'compound': -0.5267}
# {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.0772}
# {'neg': 0.073, 'neu': 0.927, 'pos': 0.0, 'compound': -0.128}
# {'neg': 0.107, 'neu': 0.807, 'pos': 0.085, 'compound': -0.1174}
# {'neg': 0.177, 'neu': 0.638, 'pos': 0.184, 'compound': 0.0516}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.379, 'neu': 0.621, 'pos': 0.0, 'compound': -0.7717}
# {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.284, 'neu': 0.433, 'pos': 0.284, 'compound': 0.0}
# {'neg': 0.396, 'neu': 0.604, 'pos': 0.0, 'compound': -0.7096}
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.149, 'neu': 0.851, 'pos': 0.0, 'compound': -0.2732}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.215, 'neu': 0.613, 'pos': 0.172, 'compound': 0.0772}
# {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.6124}
# {'neg': 0.228, 'neu': 0.517, 'pos': 0.255, 'compound': -0.119}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.6808}
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4215}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.106, 'neu': 0.894, 'pos': 0.0, 'compound': -0.2263}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.298, 'neu': 0.702, 'pos': 0.0, 'compound': -0.872}
# {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.0772}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.296}
# {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.765}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.5574}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'compound': -0.5994}
# {'neg': 0.204, 'neu': 0.717, 'pos': 0.079, 'compound': -0.5106}
# {'neg': 0.121, 'neu': 0.645, 'pos': 0.234, 'compound': 0.2013}
# {'neg': 0.344, 'neu': 0.656, 'pos': 0.0, 'compound': -0.4939}
# {'neg': 0.398, 'neu': 0.602, 'pos': 0.0, 'compound': -0.765}
# {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.3818}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.7906}
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.097, 'neu': 0.903, 'pos': 0.0, 'compound': -0.1027}
# {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3612}
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.332, 'neu': 0.668, 'pos': 0.0, 'compound': -0.7149}
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.7869}
# {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.34}
# {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2732}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.1, 'neu': 0.9, 'pos': 0.0, 'compound': -0.2247}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.3612}
# {'neg': 0.342, 'neu': 0.658, 'pos': 0.0, 'compound': -0.8316}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.5106}
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.802}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.5859}
# {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.165, 'neu': 0.567, 'pos': 0.268, 'compound': 0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.228, 'neu': 0.772, 'pos': 0.0, 'compound': -0.7096}
# {'neg': 0.119, 'neu': 0.723, 'pos': 0.158, 'compound': 0.2675}
# {'neg': 0.164, 'neu': 0.836, 'pos': 0.0, 'compound': -0.6705}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.179, 'neu': 0.625, 'pos': 0.196, 'compound': -0.1531}
# {'neg': 0.0, 'neu': 0.883, 'pos': 0.117, 'compound': 0.336}
# {'neg': 0.204, 'neu': 0.745, 'pos': 0.051, 'compound': -0.5994}
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.144, 'neu': 0.856, 'pos': 0.0, 'compound': -0.4939}
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.6369}
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.7269}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.088, 'neu': 0.775, 'pos': 0.137, 'compound': 0.2682}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'compound': -0.2263}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'compound': 0.4168}
# {'neg': 0.081, 'neu': 0.809, 'pos': 0.111, 'compound': 0.1779}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.3034}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.158, 'neu': 0.772, 'pos': 0.07, 'compound': -0.34}
# {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.6597}
# {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.3182}
# {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'compound': 0.4767}
# {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.6124}
# {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.2732}

# %%
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()
# Out:
#    Compound                      Date  Negative  Neutral Outlet  Positive  \
# 0    0.1280 2018-03-31 13:01:05+00:00     0.662    0.152   @BBC     0.185
# 1    0.0000 2018-03-31 12:31:02+00:00     1.000    0.000   @BBC     0.000
# 2   -0.3404 2018-03-31 11:50:05+00:00     0.821    0.179   @BBC     0.000
# 3    0.1779 2018-03-31 11:28:03+00:00     0.638    0.000   @BBC     0.362
# 4   -0.6351 2018-03-31 11:26:30+00:00     0.820    0.180   @BBC     0.000
#
#                                                Tweet  Tweets Ago
# 0  😂 True or false? \n@NiallOfficial screamed whe...           0
# 1  This is what happens when you get an OWL to de...           1
# 2  ✊ Don't like plastic in the supermarkets? \nWh...           2
# 3       It's still growing 😱 https://t.co/T5YocDauYj           3
# 4  RT @BBCArchive: Eh-oh! #OnThisDay 1997 the Tel...           4

# %%
#Re-ordering the DataFrame
sentiments_pd = sentiments_pd[["Outlet", "Date", "Tweet", "Compound", "Positive", "Neutral", "Negative", "Tweets Ago"]]
sentiments_pd.tail()
# Out:
#        Outlet                      Date  \
# 495  @nytimes 2018-03-30 17:28:03+00:00
# 496  @nytimes 2018-03-30 17:18:02+00:00
# 497  @nytimes 2018-03-30 17:08:04+00:00
# 498  @nytimes 2018-03-30 16:58:02+00:00
# 499  @nytimes 2018-03-30 16:48:03+00:00
#
#                                                  Tweet  Compound  Positive  \
# 495  The real marvel of Mexico’s avocado trade is n...    0.6597     0.221
# 496  The IRS is urging people to do a “paycheck che...    0.3182     0.108
# 497  RT @nytimesarts: Kate Mara on her new movie “C...    0.4767     0.129
# 498  RT @NYTStyles: The Wing is under investigation...    0.6124     0.182
# 499  In college basketball, Catholic schools have l...    0.2732     0.110
#
#      Neutral  Negative  Tweets Ago
# 495      0.0     0.779          95
# 496      0.0     0.892          96
# 497      0.0     0.871          97
# 498      0.0     0.818          98
# 499      0.0     0.890          99

# %%
#Checking to ensure I pulled all outlets
sentiments_pd["Outlet"].unique()
# Out:
# array(['@BBC', '@CBS', '@CNN', '@FoxNews', '@nytimes'], dtype=object)

# %%
#Sorting by date
sentiments_pd= sentiments_pd.sort_values("Date", ascending=False)

# %%
#Plotting
import seaborn as sns
sns.set_style("whitegrid")
plt.figure(figsize=(20,5))
plt.title("Tweet Sentiment")
plt.xlabel('Tweets Ago')
plt.ylabel('Tweet Polarity')

bbc = sentiments_pd.loc[sentiments_pd["Outlet"] == "@BBC",:]
plt.scatter(bbc["Tweets Ago"], bbc["Compound"], c='darkviolet', s=100, alpha=0.5, edgecolors="grey", linewidth=1)

cbs = sentiments_pd.loc[sentiments_pd["Outlet"] == "@CBS",:]
plt.scatter(cbs["Tweets Ago"], cbs["Compound"], c='lime', s=100, alpha=0.5, edgecolors="grey", linewidth=1,)

cnn = sentiments_pd.loc[sentiments_pd["Outlet"] == "@CNN",:]
plt.scatter(cnn["Tweets Ago"], cnn["Compound"], c='red', s=100, alpha=0.5, edgecolors="grey", linewidth=1,)

FoxNews = sentiments_pd.loc[sentiments_pd["Outlet"] == "@FoxNews",:]
plt.scatter(FoxNews["Tweets Ago"], FoxNews["Compound"], c='Orange', s=100, alpha=0.5, edgecolors="grey", linewidth=1,)

NYTimes = sentiments_pd.loc[sentiments_pd["Outlet"] == "@nytimes",:]
plt.scatter(NYTimes["Tweets Ago"], NYTimes["Compound"], c='Navy', s=100, alpha=0.5, edgecolors="grey", linewidth=1,)

BBC = mpatches.Patch(color='darkviolet', label='BBC')
CBS = mpatches.Patch(color='lime', label='CBS')
CNN = mpatches.Patch(color='red', label='CNN')
FoxNews = mpatches.Patch(color='Orange', label='FoxNews')
NYTimes = mpatches.Patch(color='Navy', label='NYTimes')
plt.legend(handles=[BBC,CBS,CNN,FoxNews,NYTimes], loc=1)
plt.savefig("Compound_Scatter.png")
plt.show()

# %%
#Grouping by outlet then creating a new DF for the bar chart
bar_prep = sentiments_pd.groupby(['Outlet'],as_index=False).mean()[['Outlet','Compound']]
bar_prep.head()
# Out:
#      Outlet  Compound
# 0      @BBC  0.059623
# 1      @CBS  0.351304
# 2      @CNN -0.027064
# 3  @FoxNews -0.044499
# 4  @nytimes  0.019097

# %%
#Bar Chart
sns.set_style("whitegrid")
plt.figure(figsize=(20,5))
plt.title("Average Media Sentiment 03/30/2018")
plt.xlabel('News Outlet')
plt.ylabel('Tweet Polarity')
my_colors = 'rgbkymc'
#Ticks
x_axis = np.arange(len(bar_prep["Outlet"]))
tick_locations = [value+0.4 for value in x_axis]
#Plot
plt.bar(x_axis, bar_prep["Compound"], color=my_colors, alpha=0.5, align="edge")
plt.xticks(tick_locations, bar_prep["Outlet"], rotation="vertical")

plt.savefig("Compound_Bar.png")
plt.show()

# %%
writer = pd.ExcelWriter('output.xlsx',options={'remove_timezone': True})
sentiments_pd.to_excel(writer,'Sheet1')

# %%
# Three Trends:
# 1) CBS usually has higher positive sentiment
# 2) Fox usually has negative sentiment
# 3) NYTimes/BBC is in the middle normally

# %%
#End of code
