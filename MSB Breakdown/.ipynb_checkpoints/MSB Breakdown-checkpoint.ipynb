# %%
import pandas as pd
import numpy as np
csv_path2 = "resource/State_emp.csv"
csv_path = "resource/US_MSB.csv"
msb = pd.read_csv(csv_path, encoding="utf-8")
emp_perc = pd.read_csv(csv_path2, encoding="utf-8")
msb.head()
# Out:
#           LEGAL NAME                  DBA NAME         STREET ADDRESS  \
# 0           $1 store              $1 store llc       110 n martin ave
# 1       $1 STORE LLC              $1 STORE LLC       110 N MARTIN AVE
# 2       $1 STORE LLC              $1 STORE LLC       110 N MARTIN AVE
# 3   0713, LLC/Andrew  About Cash - Odessa West  1410 N County Rd West
# 4  0baid/munir/gazem              jiffys store        538 central ave
#
#         CITY STATE    ZIP MSB ACTIVITIES STATES OF MSB ACTIVITIES  \
# 0  gila bend    AZ  85337            408                       AZ
# 1  GILA BEND    AZ  85337            408                       AZ
# 2  GILA BEND    AZ  85337        409 408                       AZ
# 3     Odessa    TX  79763    405 408 413                       TX
# 4    shafter    CA  93263        405 408                       CA
#
#   ALL STATES & TERRITORIES & FOREIGN FLAG** FOREIGN LOCATION  # OF BRANCHES  \
# ...

# %%
emp_perc['STATE'] = emp_perc['GEO.display-label']
emp_perc = emp_perc.drop('GEO.display-label', 1)
emp_perc = emp_perc[["STATE", "Percent Employed"]]
emp_perc.head()
# Out:
#         STATE  Percent Employed
# 0     Alabama              57.6
# 1      Alaska              67.5
# 2     Arizona              59.1
# 3    Arkansas              58.1
# 4  California              63.0

# %%
msb_df = msb[["LEGAL NAME","CITY", "STATE", "ZIP", "MSB ACTIVITIES", "AUTH SIGN DATE"]]

msb_df.head()
# Out:
#           LEGAL NAME       CITY STATE    ZIP MSB ACTIVITIES AUTH SIGN DATE
# 0           $1 store  gila bend    AZ  85337            408       1/6/2015
# 1       $1 STORE LLC  GILA BEND    AZ  85337            408      3/29/2016
# 2       $1 STORE LLC  GILA BEND    AZ  85337        409 408       5/4/2017
# 3   0713, LLC/Andrew     Odessa    TX  79763    405 408 413      1/16/2018
# 4  0baid/munir/gazem    shafter    CA  93263        405 408       4/7/2015

# %%
msb_df['STATE']=msb_df['STATE'].astype(str)
msb_df.dtypes
# Out:
# C:\Users\Craig\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# LEGAL NAME        object
# CITY              object
# STATE             object
# ZIP               object
# MSB ACTIVITIES    object
# AUTH SIGN DATE    object
# dtype: object

# %%
us_state = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VT': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
}

# %%
msb_df['STATE'] = msb_df['STATE'].map(us_state).astype(str)
msb_df.head()
# Out:
# C:\Users\Craig\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           LEGAL NAME       CITY       STATE    ZIP MSB ACTIVITIES  \
# 0           $1 store  gila bend     Arizona  85337            408
# 1       $1 STORE LLC  GILA BEND     Arizona  85337            408
# 2       $1 STORE LLC  GILA BEND     Arizona  85337        409 408
# 3   0713, LLC/Andrew     Odessa       Texas  79763    405 408 413
# 4  0baid/munir/gazem    shafter  California  93263        405 408
#
#   AUTH SIGN DATE
# 0       1/6/2015
# 1      3/29/2016
# 2       5/4/2017
# 3      1/16/2018
# 4       4/7/2015

# %%
# Merging on State
merged_df = pd.merge(msb_df, emp_perc, on="STATE")
merged_df.head()
# Out:
#                    LEGAL NAME       CITY    STATE    ZIP MSB ACTIVITIES  \
# 0                    $1 store  gila bend  Arizona  85337            408
# 1                $1 STORE LLC  GILA BEND  Arizona  85337            408
# 2                $1 STORE LLC  GILA BEND  Arizona  85337        409 408
# 3    1 2 3 MONEY EXCHANGE LLC   SAN LUIS  Arizona  85349    405 409 408
# 4  1,2,3 MONEY EXCHANGE LLC/*   SAN LUIS  Arizona  85349        408 499
#
#   AUTH SIGN DATE  Percent Employed
# 0       1/6/2015              59.1
# 1      3/29/2016              59.1
# 2       5/4/2017              59.1
# 3      5/21/2015              59.1
# 4     10/30/2017              59.1
